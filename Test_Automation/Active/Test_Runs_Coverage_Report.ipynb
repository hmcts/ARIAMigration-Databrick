# %%
#Define all Test Names for the Test Coverage Report

all_pp_tests = ['test_appealType_ac1', 'test_appealType_ac3', 'test_appealType_ac3', 'test_appealType_ac4', 'test_appealType_ac5', 'test_appealType_ac6', 'test_appealType_ac7', 'test_appealType_ac8', 'test_appealType_ac9', 'test_appealType_ac10', 'test_appealType_ac11', 'test_appealType_ac12', 'test_appealType_ac13', 'test_appealReferenceNumber_ac1', 'test_submissionOutOfTime_ac1', 'test_submissionOutOfTime_ac2', 'test_submissionOutOfTime_ac3', 'test_appealSubmissionDate', 'test_appealSubmissionInternalDate', 'test_tribunalReceivedDate', 'test_appellantsRepresentation_ac1', 'test_appellantsRepresentation_ac2', 'test_recordedOutOfTimeDecision_ac1', 'test_recordedOutOfTimeDecision_ac2', 'test_recordedOutOfTimeDecision_ac3', 'test_applicationOutOfTimeExplanation', 'hearing_centre_field_test', 'test_caseFlags', 'test_appellantFlags', 'test_isAriaMigratedFeeExemption_ac1', 'test_isAriaMigratedFeeExemption_ac2', 'test_appellantFamilyName', 'test_appellantGivenNames', 'test_appellantNameForDisplay', 'test_appellantDateOfBirth', 'test_isAppellantMinor', 'test_caseNameHmctsInternal', 'test_hmctsCaseNameInternal', 'test_internalAppellantEmail_ac1', 'test_internalAppellantEmail_ac2', 'test_email_ac1', 'test_email_ac2', 'test_internalAppellantMobileNumber_ac1', 'test_internalAppellantMobileNumber_ac2', 'test_mobileNumber_ac1', 'test_mobileNumber_ac2', 'test_appellantInUk_ac1', 'test_appellantInUk_ac2', 'test_appealOutOfCountry_ac1', 'test_appealOutOfCountry_ac2', 'test_oocAppealAdminJ_ac1', 'test_oocAppealAdminJ_ac2', 'test_oocAppealAdminJ_ac3', 'test_oocAppealAdminJ_ac4', 'test_oocAppealAdminJ_ac5', 'test_appellantAddress_ac1', 'test_appellantAddress_ac2', 'test_addressLine1AdminJ_ac1', 'test_addressLine1AdminJ_ac2', 'test_addressLine2AdminJ_ac1', 'test_addressLine2AdminJ_ac2', 'test_addressLine3AdminJ_ac1', 'test_addressLine3AdminJ_ac2', 'test_addressLine4AdminJ_ac1', 'test_addressLine4AdminJ_ac2', 'test_countryGovUkOocAdminJ_ac1', 'test_countryGovUkOocAdminJ_ac2', 'test_appellantStateless_ac1', 'test_appellantStateless_ac2', 'test_appellantNationalities', 'test_appellantNationalitiesDescription', 'test_deportationOrderOptions_ac1', 'test_deportationOrderOptions_ac2', 'test_deportationOrderOptions_ac3', 'test_deportationOrderOptions_ac3', 'test_legalRepEmail_test1', 'test_legalRepEmail_test2', 'test_legalRepEmail_test3', 'test_legalRepEmail_test4', 'test_legalRepEmail_test5', 'test_legalRepGivenName_test1', 'test_legalRepGivenName_test2', 'test_legalRepGivenName_test3', 'test_legalRepFamilyNamePaperJ_test1', 'test_legalRepFamilyNamePaperJ_test2', 'test_legalRepCompanyPaperJ_test1', 'test_legalRepCompanyPaperJ_test2', 'test_legalRepHasAddress_test1', 'test_legalRepHasAddress_test2', 'test_legalRepHasAddress_test3', 'test_legalRepAddressUK_test1', 'test_legalRepAddressUK_test2', 'test_oocAddressLine1_test1', 'test_oocAddressLine1_test2', 'test_oocAddressLine2_test1', 'test_oocAddressLine2_test2', 'test_oocAddressLine3_test1', 'test_oocAddressLine3_test2', 'test_oocAddressLine4_test1', 'test_oocAddressLine4_test2', 'test_oocLrCountryGovUkAdminJ_test1', 'test_hasSponsor_test1', 'test_hasSponsor_test2', 'test_hasSponsor_test3', 'test_sponsorGivenNames_test1', 'test_sponsorGivenNames_test2', 'test_sponsorGivenNames_test3', 'test_sponsorFamilyName_test1', 'test_sponsorFamilyName_test2', 'test_sponsorFamilyName_test3', 'test_sponsorAuthorisation_test1', 'test_sponsorAuthorisation_test2', 'test_sponsorAuthorisation_test3', 'test_sponsorAuthorisation_test4', 'test_sponsorAddress_ac1', 'test_sponsorAddress_ac2', 'test_sponsorAddress_ac3', 'test_sponsorAddress_ac4', 'test_sponsorEmailAdminJ_ac1', 'test_sponsorEmailAdminJ_ac2', 'test_sponsorEmailAdminJ_ac3', 'test_sponsorEmailAdminJ_ac4', 'test_sponsorMobileNumberAdminJ_ac1', 'test_sponsorMobileNumberAdminJ_ac2', 'test_sponsorMobileNumberAdminJ_ac3', 'test_sponsorMobileNumberAdminJ_ac4', 'test_appellantPartyId', 'test_legalRepIndividualPartyId_ac1', 'test_legalRepIndividualPartyId_ac2', 'test_legalRepOrganisationPartyId_ac1', 'test_legalRepOrganisationPartyId_ac2', 'test_sponsorPartyId_ac1', 'test_sponsorPartyId_ac2', 'test_feeAmountGbp_ac1', 'test_feeAmountGbp_ac2', 'test_feeDescription_ac1', 'test_feeDescription_ac2', 'test_feeWithHearing_ac1', 'test_feeWithHearing_ac2', 'test_feeWithoutHearing_ac1', 'test_feeWithoutHearing_ac2', 'test_paymentDescription_ac1', 'test_paymentDescription_ac2', 'test_decisionHearingFeeOption_ac1', 'test_decisionHearingFeeOption_ac2', 'test_remission_ac1', 'test_remission_ac2', 'test_remission_ac3', 'test_remission_ac4', 'test_remission_ac5', 'test_remission_ac6', 'test_remission_ac7', 'test_remission_ac8', 'test_remission_ac9', 'test_remission_ac10', 'test_remission_ac11', 'test_remission_ac12', 'test_homeOfficeDecisionDate_ac1', 'test_homeOfficeDecisionDate_ac2', 'test_decisionLetterReceivedDate_ac1', 'test_decisionLetterReceivedDate_ac2', 'test_decisionLetterReceivedDate_ac3', 'test_dateEntryClearanceDecision_ac1', 'test_dateEntryClearanceDecision_ac2', 'test_dateEntryClearanceDecision_ac3', 'test_gwfReferenceNumber_ac1', 'test_gwfReferenceNumber_ac2', 'test_gwfReferenceNumber_ac3', 'test_homeOfficeReferenceNumber_ac1', 'test_homeOfficeReferenceNumber_ac2', 'test_homeOfficeReferenceNumber_ac3', 'test_isServiceRequestTabVisibleConsideringRemissions_ac1', 'test_isServiceRequestTabVisibleConsideringRemissions_ac2', 'test_isServiceRequestTabVisibleConsideringRemissions_ac3', 'test_isServiceRequestTabVisibleConsideringRemissions_ac4', 'test_PP_defaultValues']

as_tests = ['test_AS_defaultValues', 'test_paymentStatus_test1', 'test_paymentStatus_test2', 'test_paymentStatus_test3', 'test_paymentStatus_test4', 'test_rpDcAppealHearingOption_test1', 'test_rpDcAppealHearingOption_test2', 'test_rpDcAppealHearingOption_test3', 'test_paidDate_test1', 'test_paidDate_test2', 'test_paidAmount_test1', 'test_paidAmount_test2', 'test_paymentDescription_test1', 'test_paymentDescription_test2', 'test_paymentDescription_test3', 'test_remissionDecision_test1', 'test_remissionDecision_test2', 'test_remissionDecision_test3', 'test_remissionDecisionReason_test1', 'test_remissionDecisionReason_test2', 'test_remissionDecisionReason_test3', 'test_amountLeftToPay_test1', 'test_amountLeftToPay_test2', 'test_amountLeftToPay_test3', 'test_amountRemitted_test1', 'test_amountRemitted_test2', 'test_amountRemitted_test3']


area_tests = ['test_AREA_defaultValues', 'test_appellantFullName_test1']

areb_tests = ['test_AREB_defaultValues']

cur_tests = ['test_CUR_defaultValues', 'test_hearingResponse']

rfas_tests = ['test_RFAS_defaultValues', 'test_hearingResponse']

listing_tests = ['test_Listing_defaultValues', 'test_isInterpreterServicesNeeded_test1', 'test_isInterpreterServicesNeeded_test2', 'test_isInterpreterServicesNeeded_test3', 'test_singleSexCourt_test1', 'test_singleSexCourt_test2', 'test_singleSexCourt_test3', 'test_singleSexCourtType_test1', 'test_singleSexCourtType_test2', 'test_singleSexCourtType_test3', 'test_singleSexCourtTypeDescription_test1', 'test_singleSexCourtTypeDescription_test2', 'test_singleSexCourtTypeDescription_test3', 'test_inCameraCourt_test1', 'test_inCameraCourt_test2', 'test_inCameraCourt_test3', 'test_inCameraCourtDescription_test1', 'test_inCameraCourtDescription_test2', 'test_languageInterpreterMapping']

# %%
#####Test Coverage report 1 
#Use to download and view locally
#databricks fs cp --recursive dbfs:/tmp/ ./
import functions.test_coverage as tc
import importlib
importlib.reload(tc)

tests_by_state = {
    "paymentPending" : all_pp_tests,
    "appealSubmitted": as_tests,
    "awaitingRespondentEvidence(a)": area_tests,
    "awaitingRespondentEvidence(b)": areb_tests,
    "caseUnderReview": cur_tests,
    "reasonsForAppealSubmitted": rfas_tests,
    "listing": listing_tests,

}


state_order = [
    "paymentPending",
    "appealSubmitted",
    "awaitingRespondentEvidence(a)",
    "awaitingRespondentEvidence(b)",
    "caseUnderReview",
    "reasonsForAppealSubmitted",
    "listing"
]

html = tc.generate_transformation_test_coverage_report(
    spark,
    runs_table="test_automation_runs",
    results_table="test_automation_results",    
    tests_by_state=tests_by_state,
    state_display_order=state_order,
    output_file="/dbfs/tmp/transformation_coverage.html"
)

displayHTML(html)
