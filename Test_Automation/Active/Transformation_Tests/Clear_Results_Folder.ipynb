# %%
# %fs rm -r "/Workspace/Users/peter.gresty@hmcts.net/Results/"

# %%
import sys

# results_folder = "/Workspace/Users/peter.gresty@hmcts.net/0-GIT_Test_Automation/Transformation_Tests/Results/"
results_folder = "/Workspace/Users/peter.gresty@hmcts.net/Results/"


files = dbutils.fs.ls(results_folder)

# Delete all files in that folder
for file_info in files:
    if file_info.path.endswith("/"):  # skip subfolders
        continue
    dbutils.fs.rm(file_info.path)
